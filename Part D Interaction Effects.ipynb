# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
train_model = pd.read_csv("train_model.csv")

# %%
train_model.head()
# Out:
#    Unnamed: 0  Store  DayOfWeek  Sales  Open  Promo  StateHoliday  \
# 0           0      1          5   5263     1      1             0
# 1           1      2          5   6064     1      1             0
# 2           2      3          5   8314     1      1             0
# 3           3      4          5  13995     1      1             0
# 4           4      5          5   4822     1      1             0
#
#    SchoolHoliday  Year  Month  StoreType  Assortment  CompetitionDistance  \
# 0              0     0      7        0.0         0.0               1270.0
# 1              0     0      7        1.0         0.0                570.0
# 2              0     0      7        1.0         0.0              14130.0
# 3              0     0      7        0.0         1.0                620.0
# 4              0     0      7        1.0         0.0              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# ...

# %% [markdown]
# All the variables here are independent and cannot be integrated to form interaction terms
